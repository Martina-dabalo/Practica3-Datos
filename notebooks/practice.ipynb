# %% [markdown]
# # Práctica de Data Cleaning

# %%
import pandas as pd

# %% [markdown]
# ## Objetivo
#
# El objetivo de este ejercicio es aplicar técnicas de **limpieza de datos** en Pandas.
#
# Este ejercicio cubre la manipulación de strings (utilizando métodos de strings), el uso de expresiones regulares, la importancia de la limpieza y la conversión a `datetime`
#
# ## Contexto del Conjunto de Datos
#
# Hemos cargado un DataFrame que contiene información de Presidentes de EE. UU. La columna `'Born'` (Nacimiento) contiene la fecha y, entre paréntesis, la ciudad o ubicación, como por ejemplo: `February 22, 1732[b] (Westmoreland County, Virginia)`.
#
# ## Instrucciones
#
# - De la columna `'President'` Crea una columna para el nombre 'firstname' y otra para el apellido (lastname) de los presidentes eliminando la referencias a las notas al pie que encuentres. Puedes utilizar un patron de Regular Expression para realizar esta tarea
# - La columna `'Born'` contiene referencias entre corchetes (ej. `[b]`) y texto adicional entre paréntesis (ej. `(Westmoreland County, Virginia)`). Debemos eliminar todo este texto para quedarnos solo con la fecha limpia.
# - Convierte la columna `'Born'` al Tipo `datetime`
# - Extrae de la columna  `'Born'` el año de nacimiento y genera una nueva columna denominada `'Year Born'`

# %%
df = pd.read_csv("../data/presidents.csv")

df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %% [markdown]
# # Instrucciones...

# %% [markdown]
# ## Parte 1.
# De la columna 'President' Crea una columna para el nombre 'firstname' y otra para el apellido (lastname) de los presidentes eliminando la referencias a las notas al pie que encuentres. Puedes utilizar un patron de Regular Expression para realizar esta tarea.

# %%
df['First name'] = df['President']
df['First name'] = df['First name'].replace('[ ].*', '', regex=True)
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age First name
# 0  67 years, 295 days     George
# 1  90 years, 247 days       John
# ...

# %%
df['Last name'] = df['President']
df['Last name'] = df['Last name'].str.extract('(Van Buren|\w*$)')  # Extrae Van Buren completo o los caracteres que esten al final. (se hace la excepción con 'Van Buren')
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\marti\AppData\Local\Temp\ipykernel_43164\3174978211.py:2: SyntaxWarning: invalid escape sequence '\w'
#   df['Last name'] = df['Last name'].str.extract('(Van Buren|\w*$)')  # Extrae Van Buren completo o los caracteres que esten al final. (se hace la excepción con 'Van Buren')
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# ...

# %%
# def name(row):
#        row['First name'] = row['President'].split(' ')[0]
#        row['Last name'] = row['President'].split(' ')[-1]
#        return row

# df = df.apply(name, axis='columns')
# df.head()

# %% [markdown]
# ## Parte 2.
# La columna 'Born' contiene referencias entre corchetes (ej. [b]) y texto adicional entre paréntesis (ej. (Westmoreland County, Virginia)). Debemos eliminar todo este texto para quedarnos solo con la fecha limpia.

# %%
df['Born'] = df['Born'].str.extract(r'(\w{3} \d{1,2}, \d{4})')
df.head()
# Out:
#    #          President          Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe  Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age First name   Last name
# 0  67 years, 295 days     George  Washington
# ...

# %% [markdown]
# ## Parte 3.
# Convierte la columna 'Born' al Tipo datetime.

# %%
df['Born'] = pd.to_datetime(df['Born'])
df.head()
# Out:
#    #          President       Born      Age atstart of presidency  \
# 0  1  George Washington 1732-02-22  57 years, 67 daysApr 30, 1789
# 1  2         John Adams 1735-10-30  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson 1743-04-13  57 years, 325 daysMar 4, 1801
# 3  4      James Madison 1751-03-16  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe 1758-04-28  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age First name   Last name
# 0  67 years, 295 days     George  Washington
# 1  90 years, 247 days       John       Adams
# ...

# %% [markdown]
# ## Parte 4.
# Extrae de la columna 'Born' el año de nacimiento y genera una nueva columna denominada 'Year Born'

# %%
df['Year Born'] = df['Born'].dt.year
df.head()
# Out:
#    #          President       Born      Age atstart of presidency  \
# 0  1  George Washington 1732-02-22  57 years, 67 daysApr 30, 1789
# 1  2         John Adams 1735-10-30  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson 1743-04-13  57 years, 325 daysMar 4, 1801
# 3  4      James Madison 1751-03-16  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe 1758-04-28  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age First name   Last name  Year Born
# 0  67 years, 295 days     George  Washington       1732
# ...

# %%
df.dtypes
# Out:
# #                                     int64
# President                            object
# Born                         datetime64[ns]
# Age atstart of presidency            object
# Age atend of presidency              object
# Post-presidencytimespan              object
# Died                                 object
# Age                                  object
# First name                           object
# Last name                            object
# Year Born                             int32
# dtype: object

# %% [markdown]
# # Conclusiones
# Con este trabajo aprendí a transformar datos en información estructurada y útil. Se aplicaron expresiones regulares y funciones de pandas para limpiar texto, separar nombres, extraer fechas y convertirlas en formatos analizables. Este tipo de procesamiento es esencial para preparar datos reales antes de cualquier análisis, visualización o modelado.
